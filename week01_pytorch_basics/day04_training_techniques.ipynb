# %%
import torch 
import torch.optim as optim

model = torch.nn.Linear(10, 1)
optimizer = optim.Adam(model.parameters(), lr = 1e-3)

# epoch 0-9: lr = 1e-3, epoch 10-19: lr 5e-4
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size = 10, gamma = 0.5)

# lr从1e-3平滑降到接近0，常用于Transformer训练
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=50)

# 三次loss function的值没有改变，那么会把LR减半
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)


# for epoch in range(num_epochs):
#     train_loss = train_one_epoch(...)
#     val_loss = evaluate(...)
#     scheduler.step(val_loss)
#     scheduler.step()

# %%
optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-4)

optimizer = optim.AdamW(model.parameters(), lr=1e-3, weight_decay=0.01)

# %%
import torch 
import torch.nn as nn

x = torch.randn(4, 8)

bn = nn.BatchNorm1d(8)
out_bn = bn(x)

ln = nn.LayerNorm(8)
out_ln = ln(x)

print(f"BatchNorm输出 每列(feature)的均值: {out_bn.mean(dim=0).data[:3]}") 
print(f"LayerNorm输出 每行(sample)的均值: {out_ln.mean(dim=1).data}")
# Out:
# BatchNorm输出 每列(feature)的均值: tensor([2.2352e-08, 0.0000e+00, 2.9802e-08])
# LayerNorm输出 每行(sample)的均值: tensor([-1.4901e-08,  7.4506e-09, -2.9802e-08, -1.4901e-08])
